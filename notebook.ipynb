# %%
import random
import ipaddress
import pandas as pd
from faker import Faker
import numpy as np
import json

# %%
df = pd.read_json('matrix_transition.json')
df.index = df.columns
df = df.T

# %%
df
# Out:
#                   start  landing_page  search  category_view  product_view  \
# start               0.0           1.0    0.00           0.00         0.000
# landing_page        0.0           0.0    0.20           0.25         0.150
# search              0.0           0.0    0.10           0.15         0.500
# category_view       0.0           0.0    0.10           0.05         0.550
# product_view        0.0           0.0    0.07           0.13         0.070
# add_to_cart         0.0           0.0    0.00           0.00         0.200
# cart_view           0.0           0.0    0.00           0.00         0.125
# remove_from_cart    0.0           0.0    0.00           0.00         0.300
# checkout_started    0.0           0.0    0.00           0.00         0.000
# login_success       0.0           0.0    0.00           0.00         0.000
# login_fail          0.0           0.0    0.00           0.00         0.000
# ...
